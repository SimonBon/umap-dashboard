# %%
import pandas as pd

# %%
umap_data = pd.read_feather('/data_isilon_main/isilon_images/10_MetaSystems/MetaSystemsData/Multimodal_Imaging_Daria/PIPELINE/NEWEST_RESULTS/results/UMAP_interactive/reduced_dim.feather')
expression_data = pd.read_feather('/data_isilon_main/isilon_images/10_MetaSystems/MetaSystemsData/Multimodal_Imaging_Daria/PIPELINE/NEWEST_RESULTS/results/UMAP_interactive/count_matrix.feather')
# meta_data = pd.read_feather('/data_isilon_main/isilon_images/10_MetaSystems/MetaSystemsData/Multimodal_Imaging_Daria/PIPELINE/NEWEST_RESULTS/results/UMAP_interactive/metadata.feather')
# merged_df = pd.merge(umap_data, expression_data, left_index=True, right_index=True).merge(meta_data, left_index=True, right_index=True)

import numpy as np 

permutation = np.random.permutation(umap_data.shape[0])

df1_shuffled = umap_data.iloc[permutation].reset_index(drop=True)
df2_shuffled = expression_data.iloc[permutation].reset_index(drop=True)

# %%
sliced = umap_data.iloc[:10000, :]
sliced.to_feather("/home/simon_g/src/umap_dashboard/data/umap_data.feather")

# %%
sliced = expression_data.iloc[:10000, :]
sliced.to_feather("/home/simon_g/src/umap_dashboard/data/expression_data.feather")

# %%
sliced
# Out:
#       MPO_Y89_mean  CD44_In115_mean  CD11b_Nd142_mean  HLA-DR_Nd143_mean  \
# 0         0.141667         0.000000          0.033333           0.000000
# 1         0.131818         0.335227          0.186364           0.339572
# 2         0.206897         0.000000          0.000000           0.000000
# 3         0.185455         0.000000          0.007273           0.000000
# 4         0.268000         0.000000          0.064000           0.000000
# ...            ...              ...               ...                ...
# 9995      0.186726         0.027102          0.000885           0.000000
# 9996      0.111538         0.074519          0.015385           0.000000
# 9997      0.085821         0.016791          0.013433           0.033363
# 9998      0.267273         0.000000          0.000000           0.000000
# 9999      0.037647         0.202941          0.000000           0.000000
#
#       PRPH_Nd144_mean  HLA-ABC_Sm147_mean  CD20_Nd148_mean  LUM_Sm149_mean  \
# 0                 0.0            0.142857              0.0             0.0
# 1                 0.0            0.418831              0.0             0.0
# 2                 0.0            0.104680              0.0             0.0
# 3                 0.0            0.003247              0.0             0.0
# 4                 0.0            0.627143              0.0             0.0
# ...               ...                 ...              ...             ...
# 9995              0.0            0.097977              0.0             0.0
# 9996              0.0            0.247253              0.0             0.0
# 9997              0.0            0.103145              0.0             0.0
# 9998              0.0            0.137013              0.0             0.0
# 9999              0.0            0.160504              0.0             0.0
#
#       CD11c_Nd150_mean  CD24_Eu151_mean  ...  CD279_Ho165_mean  \
# 0                  0.0         0.166667  ...               0.0
# 1                  0.0         0.000000  ...               0.0
# 2                  0.0         0.002463  ...               0.0
# 3                  0.0         0.005195  ...               0.0
# 4                  0.0         0.425714  ...               0.0
# ...                ...              ...  ...               ...
# 9995               0.0         0.012642  ...               0.0
# 9996               0.0         0.027473  ...               0.0
# 9997               0.0         0.065565  ...               0.0
# 9998               0.0         0.107792  ...               0.0
# 9999               0.0         0.000000  ...               0.0
#
#       GATA3_Er168_mean  Ki-67_Tm169_mean  CD56_Er170_mean  CD4_Yb171_mean  \
# 0                  0.0               0.0              0.0        0.000000
# 1                  0.0               0.0              0.0        0.000000
# 2                  0.0               0.0              0.0        0.000000
# 3                  0.0               0.0              0.0        0.000000
# 4                  0.0               0.0              0.0        0.000000
# ...                ...               ...              ...             ...
# 9995               0.0               0.0              0.0        0.000000
# 9996               0.0               0.0              0.0        0.000000
# 9997               0.0               0.0              0.0        0.000000
# 9998               0.0               0.0              0.0        0.000000
# 9999               0.0               0.0              0.0        0.308824
#
#       GZMB_Yb173_mean  ELAVL4_Yb174_mean  CD14_Lu175_mean  \
# 0                 0.0                0.0         0.000000
# 1                 0.0                0.0         0.000000
# 2                 0.0                0.0         0.000000
# 3                 0.0                0.0         0.000000
# 4                 0.0                0.0         0.000000
# ...               ...                ...              ...
# 9995              0.0                0.0         0.000000
# 9996              0.0                0.0         0.016144
# 9997              0.0                0.0         0.007739
# 9998              0.0                0.0         0.000673
# 9999              0.0                0.0         0.000000
#
#       Vimentin_Pt196_mean  CD15_Bi209_mean
# 0                     0.0         0.247917
# 1                     0.0         0.070455
# 2                     0.0         0.160632
# 3                     0.0         0.118636
# 4                     0.0         0.316000
# ...                   ...              ...
# 9995                  0.0         0.220059
# 9996                  0.0         0.204487
# 9997                  0.0         0.040796
# 9998                  0.0         0.276742
# 9999                  0.0         0.123431
#
# [10000 rows x 32 columns]
